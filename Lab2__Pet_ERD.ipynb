# %% [markdown]
# <a href="https://colab.research.google.com/github/kschuppius/PracticeForClass/blob/master/Lab2__Pet_ERD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#   In this Pet Shop Entity- Relationship diagram we created 6 entities.These entities include: customers, order, product, animal, enclosure,and pet food.  I decided to start it off with customer because in order to make a purchase there needs to be someone making the purchase.  In this entity I included all their information which would be linked to said customer and I also included the reward membership because its unique for each customer. Then I connected it to the order because each customer will have their own different orders including different products. which leads me to the product entity.  So for each product there will be multiple versions of each of the product so it has ro have its own unique id to differentiate between all of the same products.  So with in products I connected it to the 3  other entities which are the main items sold in the pet store including pet food, the animal that you might be purchasing, and the enclosures which includes tanks, cages,and etc.  This gives each of the items its own unique id since their are multiple types and multiple different brands of this product that the store could sell.

# %% [markdown]
# ![lab2.png](data:image/png;base64,...)
